# %% [markdown]
# # Project 2 Notebook: Clean Training & Test dataset

# %% [markdown]
# #### Load Libraries:

# %%
import numpy as np
import pandas as pd
import statistics as st
import matplotlib.pyplot as plt
import math as math
import seaborn as sns
from sklearn import metrics 
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

pd.options.display.max_rows=20
pd.options.display.max_columns=50

# %% [markdown]
# #### Load Source Data Files:

# %%
train = pd.read_csv('../datasets/train.csv')
test = pd.read_csv('../datasets/test.csv')

comb = pd.concat([train, test], sort=False)
comb.reset_index(drop=True, inplace=True)

# Edit column headers; replace embedded sapce to underscore symbol
comb.columns = comb.columns.str.strip().str.lower().str.replace(' ', '_')\
                .str.replace('(', '').str.replace(')', '').str.replace('/', '_')  

comb.to_csv('../datasets/comb.csv')

# %%
#Determine the missing data
# - investigate columns with count<2930  
comb.describe().T
# Out:
#                  count          mean           std          min           25%  \
# id              2930.0  1.465500e+03  8.459625e+02          1.0  7.332500e+02
# pid             2930.0  7.144645e+08  1.887308e+08  526301100.0  5.284770e+08
# ms_subclass     2930.0  5.738737e+01  4.263802e+01         20.0  2.000000e+01
# lot_frontage    2440.0  6.922459e+01  2.336533e+01         21.0  5.800000e+01
# lot_area        2930.0  1.014792e+04  7.880018e+03       1300.0  7.440250e+03
# overall_qual    2930.0  6.094881e+00  1.411026e+00          1.0  5.000000e+00
# overall_cond    2930.0  5.563140e+00  1.111537e+00          1.0  5.000000e+00
# year_built      2930.0  1.971356e+03  3.024536e+01       1872.0  1.954000e+03
# year_remod_add  2930.0  1.984267e+03  2.086029e+01       1950.0  1.965000e+03
# mas_vnr_area    2907.0  1.018968e+02  1.791126e+02          0.0  0.000000e+00
# ...                ...           ...           ...          ...           ...
# wood_deck_sf    2930.0  9.375188e+01  1.263616e+02          0.0  0.000000e+00
# open_porch_sf   2930.0  4.753345e+01  6.748340e+01          0.0  0.000000e+00
# enclosed_porch  2930.0  2.301160e+01  6.413906e+01          0.0  0.000000e+00
# 3ssn_porch      2930.0  2.592491e+00  2.514133e+01          0.0  0.000000e+00
# screen_porch    2930.0  1.600205e+01  5.608737e+01          0.0  0.000000e+00
# pool_area       2930.0  2.243345e+00  3.559718e+01          0.0  0.000000e+00
# misc_val        2930.0  5.063515e+01  5.663443e+02          0.0  0.000000e+00
# mo_sold         2930.0  6.216041e+00  2.714492e+00          1.0  4.000000e+00
# yr_sold         2930.0  2.007790e+03  1.316613e+00       2006.0  2.007000e+03
# saleprice       2051.0  1.814697e+05  7.925866e+04      12789.0  1.298250e+05
#
#                         50%           75%           max
# id                   1465.5  2.197750e+03  2.930000e+03
# pid             535453620.0  9.071811e+08  1.007100e+09
# ms_subclass            50.0  7.000000e+01  1.900000e+02
# lot_frontage           68.0  8.000000e+01  3.130000e+02
# lot_area             9436.5  1.155525e+04  2.152450e+05
# overall_qual            6.0  7.000000e+00  1.000000e+01
# overall_cond            5.0  6.000000e+00  9.000000e+00
# year_built           1973.0  2.001000e+03  2.010000e+03
# year_remod_add       1993.0  2.004000e+03  2.010000e+03
# mas_vnr_area            0.0  1.640000e+02  1.600000e+03
# ...                     ...           ...           ...
# wood_deck_sf            0.0  1.680000e+02  1.424000e+03
# open_porch_sf          27.0  7.000000e+01  7.420000e+02
# enclosed_porch          0.0  0.000000e+00  1.012000e+03
# 3ssn_porch              0.0  0.000000e+00  5.080000e+02
# screen_porch            0.0  0.000000e+00  5.760000e+02
# pool_area               0.0  0.000000e+00  8.000000e+02
# misc_val                0.0  0.000000e+00  1.700000e+04
# mo_sold                 6.0  8.000000e+00  1.200000e+01
# yr_sold              2008.0  2.009000e+03  2.010000e+03
# saleprice          162500.0  2.140000e+05  6.116570e+05
#
# [39 rows x 8 columns]

# %% [markdown]
# ##### lot_frontage:

# %%
comb[comb['lot_frontage'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 7      145  535154050           20        RL           NaN     12160   Pave
# 8     1942  535353130           20        RL           NaN     15783   Pave
# 23      12  527165230           20        RL           NaN      7980   Pave
# 27    1534  909277040           50        RL           NaN     11700   Pave
# 31    2860  909276010           70        RL           NaN     11435   Pave
# 42     983  923275040           85        RL           NaN      9101   Pave
# 50    2511  533221080          160        FV           NaN      2998   Pave
# 59     997  527107010           60        RL           NaN     15038   Pave
# 62     230  905109170           20        RL           NaN     20062   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2884   872  907275140           20        RL           NaN     12782   Pave
# 2891  2538  534202020           20        RL           NaN      9759   Pave
# 2894   233  905325030           40        RL           NaN     23595   Pave
# 2898   137  535125010           20        RL           NaN     19900   Pave
# 2903   599  534252240           20        RL           NaN      9790   Pave
# 2905  2582  535301010           90        RL           NaN      7032   Pave
# 2911   984  923275140           20        RL           NaN      8780   Pave
# 2918  2271  916460020           20        RL           NaN      7777   Pave
# 2919  1633  527182170          160        RL           NaN      5062   Pave
# 2921  2765  906426090           20        RL           NaN     36500   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 0      NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 7      NaN       IR1          Lvl    AllPub     Inside        Gtl
# 8      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 23     NaN       IR1          Lvl    AllPub     Inside        Gtl
# 27    Grvl       IR1          HLS    AllPub     Inside        Mod
# 31     NaN       IR1          HLS    AllPub     Corner        Mod
# 42     NaN       IR1          Lvl    AllPub     Corner        Gtl
# 50     NaN       Reg          Lvl    AllPub     Inside        Gtl
# 59     NaN       IR2          Lvl    AllPub     Corner        Gtl
# 62     NaN       IR1          Low    AllPub     Inside        Mod
# ...    ...       ...          ...       ...        ...        ...
# 2884   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2891   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 2894   NaN       Reg          Low    AllPub     Inside        Sev
# 2898   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2903   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2905   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 2911   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 2918   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 2919   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 2921   NaN       IR1          Low    AllPub     Inside        Mod
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 0          Sawyer        RRAe        Norm      1Fam      2Story             6
# 7           NAmes        Norm        Norm      1Fam      1Story             5
# 8         OldTown      Artery        Norm      1Fam      1Story             5
# 23        Gilbert        Norm        Norm      1Fam      1Story             6
# 27        Crawfor        Norm        Norm      1Fam      1.5Fin             5
# 31        Crawfor        Norm        Norm      1Fam      2Story             8
# 42        Mitchel        Norm        Norm      1Fam      SFoyer             5
# 50        Somerst        Norm        Norm    TwnhsE      2Story             6
# 59        Gilbert        Norm        Norm      1Fam      2Story             6
# 62        ClearCr        Norm        Norm      1Fam      1Story             7
# ...           ...         ...         ...       ...         ...           ...
# 2884      CollgCr        Norm        Norm      1Fam      1Story             8
# 2891        NAmes        Norm        Norm      1Fam      1Story             5
# 2894      ClearCr        Norm        Norm      1Fam      1Story             7
# 2898        NAmes        PosA        Norm      1Fam      1Story             7
# 2903       NWAmes       Feedr        Norm      1Fam      1Story             6
# 2905        NAmes        Norm        Norm    Duplex      SFoyer             5
# 2911      Mitchel        Norm        Norm      1Fam      1Story             5
# 2918       Timber        Norm        Norm      1Fam      1Story             6
# 2919      StoneBr        Norm        Norm    TwnhsE      2Story             7
# 2921      ClearCr        Norm        Norm      1Fam      1Story             5
#
#       overall_cond  year_built  year_remod_add roof_style roof_matl  \
# 0                8        1976            2005      Gable   CompShg
# 7                5        1959            1959        Hip   CompShg
# 8                5        1952            1952      Gable   CompShg
# 23               7        1992            2007      Gable   CompShg
# 27               6        1937            1995      Gable   CompShg
# 31               7        1929            1950      Gable   CompShg
# 42               6        1978            1978      Gable   CompShg
# 50               5        2000            2000      Gable   CompShg
# 59               5        1996            1996      Gable   CompShg
# 62               7        1977            2001        Hip   CompShg
# ...            ...         ...             ...        ...       ...
# 2884             5        2002            2003        Hip   CompShg
# 2891             5        1966            1966      Gable   CompShg
# 2894             6        1979            1979       Shed   WdShake
# 2898             5        1970            1989      Gable   CompShg
# 2903             5        1967            1967      Gable   CompShg
# 2905             5        1979            1979      Gable   CompShg
# 2911             5        1985            1985      Gable   CompShg
# 2918             5        1996            1996      Gable   CompShg
# 2919             5        1984            1984      Gable   CompShg
# 2921             5        1964            1964      Gable   CompShg
#
#      exterior_1st  ... functional fireplaces  fireplace_qu garage_type  \
# 0         HdBoard  ...        Typ          0           NaN      Attchd
# 7         Plywood  ...        Typ          0           NaN      Attchd
# 8         Wd Sdng  ...        Typ          0           NaN      Detchd
# 23        HdBoard  ...        Typ          0           NaN      Attchd
# 27        WdShing  ...       Min2          1            Gd      Detchd
# 31        BrkFace  ...        Typ          2            Gd      Detchd
# 42        Plywood  ...        Typ          1            TA      Attchd
# 50        MetalSd  ...        Typ          0           NaN      Detchd
# 59        HdBoard  ...        Typ          1            TA      Attchd
# 62        Wd Sdng  ...        Typ          2            TA      Attchd
# ...           ...  ...        ...        ...           ...         ...
# 2884      HdBoard  ...        Typ          1            Gd      Attchd
# 2891      Plywood  ...        Typ          0           NaN      Attchd
# 2894      Plywood  ...        Typ          1            TA      Attchd
# 2898      Plywood  ...       Min1          1            Gd      Attchd
# 2903      BrkFace  ...        Typ          1            Gd      Attchd
# 2905      MetalSd  ...        Typ          2            TA      Detchd
# 2911      HdBoard  ...        Typ          0           NaN         NaN
# 2918      VinylSd  ...        Typ          1            TA      Attchd
# 2919      HdBoard  ...       Min1          1            TA      Attchd
# 2921      Wd Sdng  ...        Typ          0           NaN      Attchd
#
#      garage_yr_blt garage_finish garage_cars garage_area garage_qual  \
# 0           1976.0           RFn         2.0       475.0          TA
# 7           1959.0           RFn         2.0       531.0          TA
# 8           1952.0           Unf         1.0       420.0          TA
# 23          1992.0           Fin         2.0       420.0          TA
# 27          1937.0           Unf         1.0       240.0          TA
# 31          1931.0           Unf         2.0       400.0          TA
# 42          1978.0           Fin         2.0       602.0          TA
# 50          2000.0           Unf         2.0       440.0          TA
# 59          1996.0           Fin         2.0       386.0          TA
# 62          1977.0           RFn         2.0       690.0          TA
# ...            ...           ...         ...         ...         ...
# 2884        2002.0           Fin         2.0       523.0          TA
# 2891        1966.0           RFn         1.0       264.0          TA
# 2894        1979.0           Fin         2.0       586.0          TA
# 2898        1970.0           RFn         2.0       576.0          TA
# 2903        1967.0           Unf         2.0       457.0          TA
# 2905        1979.0           Unf         2.0       600.0          TA
# 2911           NaN           NaN         0.0         0.0         NaN
# 2918        1996.0           Fin         2.0       571.0          TA
# 2919        1984.0           Fin         2.0       577.0          TA
# 2921        1964.0           Unf         2.0       390.0          TA
#
#      garage_cond  paved_drive wood_deck_sf  open_porch_sf  enclosed_porch  \
# 0             TA            Y            0             44               0
# 7             TA            Y            0              0               0
# 8             TA            Y            0            324               0
# 23            TA            Y          483             21               0
# 27            TA            Y            0             40               0
# 31            TA            Y            0              0               0
# 42            TA            Y          303             30               0
# 50            TA            Y            0             32               0
# 59            TA            Y          168             84               0
# 62            TA            Y          496              0               0
# ...          ...          ...          ...            ...             ...
# 2884          TA            Y          194            144               0
# 2891          TA            Y          182             88               0
# 2894          TA            Y          268              0               0
# 2898          TA            Y          301              0               0
# 2903          TA            Y            0              0               0
# 2905          TA            Y           42              0               0
# 2911         NaN            Y            0              0               0
# 2918          TA            Y            0             35               0
# 2919          TA            Y          219              0               0
# 2921          TA            N          168            198               0
#
#       3ssn_porch screen_porch pool_area pool_qc  fence  misc_feature  \
# 0              0            0         0     NaN    NaN           NaN
# 7              0            0         0     NaN  MnPrv           NaN
# 8              0            0         0     NaN  MnPrv          Shed
# 23             0            0         0     NaN  GdPrv          Shed
# 27             0            0         0     NaN    NaN           NaN
# 31             0            0         0     NaN    NaN           NaN
# 42             0            0         0     NaN    NaN           NaN
# 50             0            0         0     NaN    NaN           NaN
# 59             0            0         0     NaN    NaN           NaN
# 62             0            0         0     NaN    NaN           NaN
# ...          ...          ...       ...     ...    ...           ...
# 2884           0            0         0     NaN    NaN           NaN
# 2891           0            0         0     NaN    NaN           NaN
# 2894           0            0         0     NaN    NaN           NaN
# 2898           0            0         0     NaN    NaN           NaN
# 2903           0          197         0     NaN    NaN           NaN
# 2905           0            0         0     NaN    NaN           NaN
# 2911           0            0         0     NaN  MnPrv           NaN
# 2918           0            0         0     NaN    NaN           NaN
# 2919           0            0         0     NaN    NaN           NaN
# 2921           0            0         0     NaN    NaN           NaN
#
#       misc_val  mo_sold  yr_sold  sale_type  saleprice
# 0            0        3     2010        WD    130500.0
# 7            0        5     2010        COD   142000.0
# 8          400        6     2007        WD    112500.0
# 23         500        3     2010        WD    185000.0
# 27           0        7     2008        WD    198000.0
# 31           0        6     2006        WD    230000.0
# 42           0        7     2009        WD    165500.0
# 50           0        6     2006        WD    166000.0
# 59           0       11     2008        WD    173000.0
# 62           0        4     2010        WD    270000.0
# ...        ...      ...      ...        ...        ...
# 2884         0        6     2009        WD         NaN
# 2891         0        3     2006        WD         NaN
# 2894         0        4     2010        WD         NaN
# 2898         0        7     2010        WD         NaN
# 2903         0        9     2009        WD         NaN
# 2905         0       12     2006        WD         NaN
# 2911         0        3     2009        WD         NaN
# 2918         0       11     2007        WD         NaN
# 2919         0        9     2007        WD         NaN
# 2921         0        6     2006        WD         NaN
#
# [490 rows x 81 columns]

# %%
comb.fillna(value={'lot_frontage':68},inplace=True) #Replace missing lot_frontage values with median value

# %%
comb[comb['lot_frontage'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, pid, ms_subclass, ms_zoning, lot_frontage, lot_area, street, alley, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod_add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, fireplace_qu, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, pool_qc, fence, misc_feature, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []
#
# [0 rows x 81 columns]

# %% [markdown]
# ##### alley:

# %%
comb[comb['alley'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0      109  533352170           60        RL          68.0     13517   Pave
# 1      544  531379050           60        RL          43.0     11492   Pave
# 2      153  535304180           20        RL          68.0      7922   Pave
# 3      318  916386060           60        RL          73.0      9802   Pave
# 4      255  906425045           50        RL          82.0     14235   Pave
# 5      138  535126040           20        RL         137.0     16492   Pave
# 6     2827  908186070          180        RM          35.0      3675   Pave
# 7      145  535154050           20        RL          68.0     12160   Pave
# 8     1942  535353130           20        RL          68.0     15783   Pave
# 9     1956  535426130           60        RL          70.0     11606   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2920   337  923276250           90        RL          70.0      7700   Pave
# 2921  2765  906426090           20        RL          68.0     36500   Pave
# 2922  1746  528231010           20        RL         182.0     14572   Pave
# 2923   368  527254020           20        RL          80.0     11844   Pave
# 2924  2806  907401050           20        RL          70.0      8810   Pave
# 2925  1662  527377110           60        RL          80.0      8000   Pave
# 2926  1234  535126140           60        RL          90.0     14670   Pave
# 2927  1373  904100040           20        RL          55.0      8250   Pave
# 2928  1672  527425140           20        RL          60.0      9000   Pave
# 2929  1939  535327160           20        RL          70.0      8400   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 0      NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1      NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 2      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 3      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 4      NaN       IR1          Lvl    AllPub     Inside        Gtl
# 5      NaN       IR1          Lvl    AllPub     Corner        Gtl
# 6      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 7      NaN       IR1          Lvl    AllPub     Inside        Gtl
# 8      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 9      NaN       IR1          HLS    AllPub     Inside        Sev
# ...    ...       ...          ...       ...        ...        ...
# 2920   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2921   NaN       IR1          Low    AllPub     Inside        Mod
# 2922   NaN       IR3          Lvl    AllPub     Corner        Gtl
# 2923   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 2924   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2925   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2926   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2927   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2928   NaN       Reg          Lvl    AllPub        FR2        Gtl
# 2929   NaN       Reg          Lvl    AllPub     Corner        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 0          Sawyer        RRAe        Norm      1Fam      2Story             6
# 1         SawyerW        Norm        Norm      1Fam      2Story             7
# 2           NAmes        Norm        Norm      1Fam      1Story             5
# 3          Timber        Norm        Norm      1Fam      2Story             5
# 4         SawyerW        Norm        Norm      1Fam      1.5Fin             6
# 5           NAmes        PosA        Norm      1Fam      1Story             6
# 6         Edwards        Norm        Norm    TwnhsE      SFoyer             6
# 7           NAmes        Norm        Norm      1Fam      1Story             5
# 8         OldTown      Artery        Norm      1Fam      1Story             5
# 9           NAmes        Norm        Norm      1Fam      2Story             5
# ...           ...         ...         ...       ...         ...           ...
# 2920      Mitchel        Norm        Norm    Duplex      2Story             5
# 2921      ClearCr        Norm        Norm      1Fam      1Story             5
# 2922      Gilbert        Norm        Norm      1Fam      1Story             7
# 2923      StoneBr        Norm        Norm      1Fam      1Story             8
# 2924      CollgCr        Norm        Norm      1Fam      1Story             7
# 2925       NWAmes        PosN        Norm      1Fam      2Story             6
# 2926        NAmes        Norm        Norm      1Fam      2Story             6
# 2927       Sawyer       Feedr        Norm      1Fam      1Story             5
# 2928        NAmes        Norm        Norm      1Fam      1Story             4
# 2929        NAmes        Norm        Norm      1Fam      1Story             5
#
#       overall_cond  year_built  year_remod_add roof_style roof_matl  \
# 0                8        1976            2005      Gable   CompShg
# 1                5        1996            1997      Gable   CompShg
# 2                7        1953            2007      Gable   CompShg
# 3                5        2006            2007      Gable   CompShg
# 4                8        1900            1993      Gable   CompShg
# 5                6        1966            2002      Gable   CompShg
# 6                5        2005            2006      Gable   CompShg
# 7                5        1959            1959        Hip   CompShg
# 8                5        1952            1952      Gable   CompShg
# 9                5        1969            1969      Gable   CompShg
# ...            ...         ...             ...        ...       ...
# 2920             2        1985            1986      Gable   CompShg
# 2921             5        1964            1964      Gable   CompShg
# 2922             5        2004            2004        Hip   CompShg
# 2923             5        2008            2008        Hip   CompShg
# 2924             5        2003            2003      Gable   CompShg
# 2925             6        1974            1974      Gable   CompShg
# 2926             7        1966            1999      Gable   CompShg
# 2927             5        1968            1968        Hip   CompShg
# 2928             6        1971            1971      Gable   CompShg
# 2929             5        1955            1955      Gable   CompShg
#
#      exterior_1st  ... functional fireplaces  fireplace_qu garage_type  \
# 0         HdBoard  ...        Typ          0           NaN      Attchd
# 1         VinylSd  ...        Typ          1            TA      Attchd
# 2         VinylSd  ...        Typ          0           NaN      Detchd
# 3         VinylSd  ...        Typ          0           NaN     BuiltIn
# 4         Wd Sdng  ...        Typ          0           NaN      Detchd
# 5         BrkFace  ...        Mod          1            Gd      Attchd
# 6         VinylSd  ...        Typ          0           NaN     Basment
# 7         Plywood  ...        Typ          0           NaN      Attchd
# 8         Wd Sdng  ...        Typ          0           NaN      Detchd
# 9         Plywood  ...        Typ          2            TA      Attchd
# ...           ...  ...        ...        ...           ...         ...
# 2920      HdBoard  ...        Typ          0           NaN      Attchd
# 2921      Wd Sdng  ...        Typ          0           NaN      Attchd
# 2922      VinylSd  ...        Typ          1            Gd      Attchd
# 2923      VinylSd  ...        Typ          1            Gd      Attchd
# 2924      VinylSd  ...        Typ          0           NaN      Attchd
# 2925      HdBoard  ...        Typ          1            TA      Attchd
# 2926      VinylSd  ...        Typ          1            Gd      Attchd
# 2927      HdBoard  ...        Typ          1            TA      Attchd
# 2928      HdBoard  ...        Typ          0           NaN      Detchd
# 2929      MetalSd  ...        Typ          2            TA      Attchd
#
#      garage_yr_blt garage_finish garage_cars garage_area garage_qual  \
# 0           1976.0           RFn         2.0       475.0          TA
# 1           1997.0           RFn         2.0       559.0          TA
# 2           1953.0           Unf         1.0       246.0          TA
# 3           2007.0           Fin         2.0       400.0          TA
# 4           1957.0           Unf         2.0       484.0          TA
# 5           1966.0           Fin         2.0       578.0          TA
# 6           2005.0           Fin         2.0       525.0          TA
# 7           1959.0           RFn         2.0       531.0          TA
# 8           1952.0           Unf         1.0       420.0          TA
# 9           1969.0           Unf         2.0       504.0          TA
# ...            ...           ...         ...         ...         ...
# 2920        1985.0           Unf         2.0       616.0          TA
# 2921        1964.0           Unf         2.0       390.0          TA
# 2922        2004.0           Fin         3.0       630.0          TA
# 2923        2008.0           Fin         3.0       834.0          TA
# 2924        2003.0           RFn         2.0       545.0          TA
# 2925        1974.0           Unf         2.0       488.0          TA
# 2926        1966.0           RFn         2.0       480.0          TA
# 2927        1968.0           Unf         1.0       322.0          TA
# 2928        1974.0           Unf         2.0       528.0          TA
# 2929        1955.0           Unf         1.0       390.0          TA
#
#      garage_cond  paved_drive wood_deck_sf  open_porch_sf  enclosed_porch  \
# 0             TA            Y            0             44               0
# 1             TA            Y            0             74               0
# 2             TA            Y            0             52               0
# 3             TA            Y          100              0               0
# 4             TA            N            0             59               0
# 5             TA            Y            0              0               0
# 6             TA            Y            0             44               0
# 7             TA            Y            0              0               0
# 8             TA            Y            0            324               0
# 9             TA            Y          335              0               0
# ...          ...          ...          ...            ...             ...
# 2920          Fa            Y          200              0               0
# 2921          TA            N          168            198               0
# 2922          TA            Y          144             36               0
# 2923          TA            Y          322             82               0
# 2924          TA            Y            0             68               0
# 2925          TA            Y            0             96               0
# 2926          TA            Y            0            230               0
# 2927          TA            Y            0             63               0
# 2928          TA            Y            0              0               0
# 2929          TA            Y           81              0               0
#
#       3ssn_porch screen_porch pool_area pool_qc  fence  misc_feature  \
# 0              0            0         0     NaN    NaN           NaN
# 1              0            0         0     NaN    NaN           NaN
# 2              0            0         0     NaN    NaN           NaN
# 3              0            0         0     NaN    NaN           NaN
# 4              0            0         0     NaN    NaN           NaN
# 5              0            0         0     NaN    NaN           NaN
# 6              0            0         0     NaN    NaN           NaN
# 7              0            0         0     NaN  MnPrv           NaN
# 8              0            0         0     NaN  MnPrv          Shed
# 9              0            0         0     NaN    NaN           NaN
# ...          ...          ...       ...     ...    ...           ...
# 2920           0            0         0     NaN    NaN          Shed
# 2921           0            0         0     NaN    NaN           NaN
# 2922           0            0         0     NaN    NaN           NaN
# 2923           0            0         0     NaN    NaN           NaN
# 2924           0            0         0     NaN    NaN           NaN
# 2925           0            0         0     NaN    NaN           NaN
# 2926           0            0         0     NaN  MnPrv           NaN
# 2927           0            0         0     NaN    NaN           NaN
# 2928           0            0         0     NaN   GdWo           NaN
# 2929           0            0         0     NaN   GdWo           NaN
#
#       misc_val  mo_sold  yr_sold  sale_type  saleprice
# 0            0        3     2010        WD    130500.0
# 1            0        4     2009        WD    220000.0
# 2            0        1     2010        WD    109000.0
# 3            0        4     2010        WD    174000.0
# 4            0        3     2010        WD    138500.0
# 5            0        6     2010        WD    190000.0
# 6            0        6     2006        New   140000.0
# 7            0        5     2010        COD   142000.0
# 8          400        6     2007        WD    112500.0
# 9            0        9     2007        WD    135000.0
# ...        ...      ...      ...        ...        ...
# 2920       600        2     2010        WD         NaN
# 2921         0        6     2006        WD         NaN
# 2922         0       11     2007        WD         NaN
# 2923         0        7     2009        New        NaN
# 2924         0        3     2006        WD         NaN
# 2925         0       11     2007        WD         NaN
# 2926         0        8     2008        WD         NaN
# 2927         0        8     2008        WD         NaN
# 2928         0        5     2007        WD         NaN
# 2929         0        3     2007        WD         NaN
#
# [2732 rows x 81 columns]

# %%
comb['alley'].fillna(value='NA',inplace=True)          #Replace missing alley values with 'NA'

# %%
comb[comb['alley'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, pid, ms_subclass, ms_zoning, lot_frontage, lot_area, street, alley, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod_add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, fireplace_qu, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, pool_qc, fence, misc_feature, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []
#
# [0 rows x 81 columns]

# %% [markdown]
# ##### mas_vnr_type:

# %%
comb[comb['mas_vnr_type'].isnull()].head()
# Out:
#        id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 22   2393  528142010           60        RL         103.0     12867   Pave
# 41   2383  528110050           20        RL         107.0     13891   Pave
# 86    539  531371050           20        RL          67.0     10083   Pave
# 212   518  528458020           20        FV          90.0      7993   Pave
# 276  2824  908130020           20        RL          75.0      8050   Pave
#
#     alley lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 22     NA       IR1          Lvl    AllPub     Corner        Gtl      NridgHt
# 41     NA       Reg          Lvl    AllPub     Inside        Gtl      NridgHt
# 86     NA       Reg          Lvl    AllPub     Inside        Gtl      SawyerW
# 212    NA       IR1          Lvl    AllPub     Inside        Gtl      Somerst
# 276    NA       Reg          Lvl    AllPub     Inside        Gtl      Edwards
#
#     condition_1 condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 22         Norm        Norm      1Fam      2Story             8             5
# 41         Norm        Norm      1Fam      1Story            10             5
# 86         Norm        Norm      1Fam      1Story             7             5
# 212        Norm        Norm      1Fam      1Story             7             5
# 276        Norm        Norm      1Fam      1Story             6             5
#
#      year_built  year_remod_add roof_style roof_matl exterior_1st  ...  \
# 22         2005            2006      Gable   CompShg      CemntBd  ...
# 41         2006            2006      Gable   CompShg      VinylSd  ...
# 86         2003            2003      Gable   CompShg      VinylSd  ...
# 212        2008            2009      Gable   CompShg      VinylSd  ...
# 276        2002            2002      Gable   CompShg      VinylSd  ...
#
#     functional fireplaces  fireplace_qu garage_type garage_yr_blt  \
# 22         Typ          1            Gd      Attchd        2005.0
# 41         Typ          1            Gd      Attchd        2006.0
# 86         Typ          0           NaN      Attchd        2003.0
# 212        Typ          0           NaN      Attchd        2008.0
# 276        Typ          0           NaN         NaN           NaN
#
#     garage_finish garage_cars garage_area garage_qual garage_cond  \
# 22            Fin         2.0       575.0          TA          TA
# 41            Fin         3.0       850.0          TA          TA
# 86            RFn         2.0       555.0          TA          TA
# 212           Fin         2.0       529.0          TA          TA
# 276           NaN         0.0         0.0         NaN         NaN
#
#      paved_drive wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 22             Y          243            142               0           0
# 41             Y          216            229               0           0
# 86             Y            0             41               0           0
# 212            Y            0            121               0           0
# 276            N           32              0               0           0
#
#     screen_porch pool_area pool_qc fence  misc_feature  misc_val  mo_sold  \
# 22             0         0     NaN   NaN           NaN         0        7
# 41             0         0     NaN   NaN           NaN         0        9
# 86             0         0     NaN   NaN           NaN         0        8
# 212            0         0     NaN   NaN           NaN         0       10
# 276            0         0     NaN   NaN           NaN         0        4
#
#      yr_sold  sale_type  saleprice
# 22      2006        New   344133.0
# 41      2006        New   465000.0
# 86      2009        WD    184900.0
# 212     2009        New   225000.0
# 276     2006        WD    117250.0
#
# [5 rows x 81 columns]

# %%
comb['mas_vnr_type'].fillna(value='None',inplace=True)       #Replace missing mas_vnr_type values with 'None'

# %%
comb[comb['mas_vnr_type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, pid, ms_subclass, ms_zoning, lot_frontage, lot_area, street, alley, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod_add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, fireplace_qu, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, pool_qc, fence, misc_feature, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []
#
# [0 rows x 81 columns]

# %% [markdown]
# ##### mas_vnr_area:

# %%
comb[comb['mas_vnr_area'].isnull()].head()
# Out:
#        id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 22   2393  528142010           60        RL         103.0     12867   Pave
# 41   2383  528110050           20        RL         107.0     13891   Pave
# 86    539  531371050           20        RL          67.0     10083   Pave
# 212   518  528458020           20        FV          90.0      7993   Pave
# 276  2824  908130020           20        RL          75.0      8050   Pave
#
#     alley lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 22     NA       IR1          Lvl    AllPub     Corner        Gtl      NridgHt
# 41     NA       Reg          Lvl    AllPub     Inside        Gtl      NridgHt
# 86     NA       Reg          Lvl    AllPub     Inside        Gtl      SawyerW
# 212    NA       IR1          Lvl    AllPub     Inside        Gtl      Somerst
# 276    NA       Reg          Lvl    AllPub     Inside        Gtl      Edwards
#
#     condition_1 condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 22         Norm        Norm      1Fam      2Story             8             5
# 41         Norm        Norm      1Fam      1Story            10             5
# 86         Norm        Norm      1Fam      1Story             7             5
# 212        Norm        Norm      1Fam      1Story             7             5
# 276        Norm        Norm      1Fam      1Story             6             5
#
#      year_built  year_remod_add roof_style roof_matl exterior_1st  ...  \
# 22         2005            2006      Gable   CompShg      CemntBd  ...
# 41         2006            2006      Gable   CompShg      VinylSd  ...
# 86         2003            2003      Gable   CompShg      VinylSd  ...
# 212        2008            2009      Gable   CompShg      VinylSd  ...
# 276        2002            2002      Gable   CompShg      VinylSd  ...
#
#     functional fireplaces  fireplace_qu garage_type garage_yr_blt  \
# 22         Typ          1            Gd      Attchd        2005.0
# 41         Typ          1            Gd      Attchd        2006.0
# 86         Typ          0           NaN      Attchd        2003.0
# 212        Typ          0           NaN      Attchd        2008.0
# 276        Typ          0           NaN         NaN           NaN
#
#     garage_finish garage_cars garage_area garage_qual garage_cond  \
# 22            Fin         2.0       575.0          TA          TA
# 41            Fin         3.0       850.0          TA          TA
# 86            RFn         2.0       555.0          TA          TA
# 212           Fin         2.0       529.0          TA          TA
# 276           NaN         0.0         0.0         NaN         NaN
#
#      paved_drive wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 22             Y          243            142               0           0
# 41             Y          216            229               0           0
# 86             Y            0             41               0           0
# 212            Y            0            121               0           0
# 276            N           32              0               0           0
#
#     screen_porch pool_area pool_qc fence  misc_feature  misc_val  mo_sold  \
# 22             0         0     NaN   NaN           NaN         0        7
# 41             0         0     NaN   NaN           NaN         0        9
# 86             0         0     NaN   NaN           NaN         0        8
# 212            0         0     NaN   NaN           NaN         0       10
# 276            0         0     NaN   NaN           NaN         0        4
#
#      yr_sold  sale_type  saleprice
# 22      2006        New   344133.0
# 41      2006        New   465000.0
# 86      2009        WD    184900.0
# 212     2009        New   225000.0
# 276     2006        WD    117250.0
#
# [5 rows x 81 columns]

# %%
comb['mas_vnr_area'] = comb['mas_vnr_area'].fillna(0)      #Replace missing  values with 'zero

# %%
comb[comb['mas_vnr_area'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, pid, ms_subclass, ms_zoning, lot_frontage, lot_area, street, alley, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod_add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, fireplace_qu, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, pool_qc, fence, misc_feature, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []
#
# [0 rows x 81 columns]

# %% [markdown]
# ##### All bsmt features:

# %%
comb[comb['bsmt_cond'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 12     807  906226060           70        RL         120.0     26400   Pave
# 93     811  906226100           90        RL          64.0      7018   Pave
# 114    781  905228050           20        RL          68.0      9000   Pave
# 146    888  908128060           85        RL          64.0      7301   Pave
# 183   1554  910251050           20   A (agr)          80.0     14584   Pave
# 240   2740  905451050           20        RL          80.0     12048   Pave
# 249   2242  910206010           50        RM          64.0     11067   Pave
# 256   2745  905477010           20        RL          77.0      8335   Pave
# 390     84  532351140           90        RM          68.0      8930   Pave
# 437   1501  908201100           90        RL          65.0      6040   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2532   795  905475500           20        RL          68.0     11500   Pave
# 2579   276  908102130           90        RL          75.0      9825   Pave
# 2604  1344  903232030           30        RM          68.0      6120   Pave
# 2665  2213  909275160           20        RL         126.0     13108   Pave
# 2670  2185  908204180           90        RL          74.0      6882   Pave
# 2673   808  906226070           90        RL          64.0      7018   Pave
# 2677  1818  531477040           90        RH          60.0      8400   Pave
# 2706  1220  534451080           20        RL          68.0      6627   Pave
# 2754   552  531475220           90        RL          75.0      8250   Pave
# 2823  2617  535425050           20        RL          86.0     11650   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 12      NA       Reg          Bnk    AllPub        FR2        Gtl
# 93      NA       Reg          Bnk    AllPub     Inside        Gtl
# 114     NA       Reg          Lvl    AllPub     Corner        Gtl
# 146     NA       Reg          Lvl    AllPub     Corner        Gtl
# 183     NA       Reg          Low    AllPub     Inside        Mod
# 240     NA       Reg          Lvl    AllPub     Inside        Gtl
# 249     NA       Reg          Lvl    AllPub     Corner        Gtl
# 256     NA       Reg          Lvl    AllPub     Corner        Gtl
# 390     NA       Reg          Lvl    AllPub     Inside        Gtl
# 437     NA       Reg          Lvl    AllPub     Inside        Gtl
# ...    ...       ...          ...       ...        ...        ...
# 2532    NA       IR1          Lvl    AllPub    CulDSac        Gtl
# 2579    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2604    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2665    NA       IR2          HLS    AllPub     Inside        Gtl
# 2670    NA       Reg          Lvl    AllPub     Corner        Gtl
# 2673    NA       Reg          Bnk    AllPub     Inside        Gtl
# 2677    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2706    NA       IR1          Lvl    AllPub     Corner        Gtl
# 2754    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2823    NA       Reg          Lvl    AllPub     Corner        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 12        SawyerW       Feedr        Norm      1Fam      2Story             5
# 93        SawyerW        Norm        Norm    Duplex      1Story             5
# 114        Sawyer        Norm        Norm      1Fam      1Story             2
# 146       Edwards        Norm        Norm      1Fam      SFoyer             7
# 183        IDOTRR        Norm        Norm      1Fam      1Story             1
# 240       Edwards        Norm        Norm      1Fam      1Story             5
# 249        IDOTRR        Norm        Norm      1Fam      1.5Fin             2
# 256       Edwards        Norm        Norm      1Fam      1Story             5
# 390        Sawyer        RRAe        Norm    Duplex      1.5Fin             6
# 437       Edwards        Norm        Norm    Duplex      1Story             4
# ...           ...         ...         ...       ...         ...           ...
# 2532      Edwards        Norm        Norm      1Fam      1Story             4
# 2579      Edwards        Norm        Norm    Duplex      1Story             5
# 2604      BrkSide        Norm        Norm      1Fam      1Story             5
# 2665      Crawfor        Norm        Norm      1Fam      1Story             5
# 2670      Edwards        Norm        Norm    Duplex      1Story             4
# 2673      SawyerW        Norm        Norm    Duplex      1Story             5
# 2677      SawyerW       Feedr        Norm    Duplex      1Story             5
# 2706      BrkSide       Feedr        Norm      1Fam      1Story             3
# 2754      SawyerW        Norm        Norm    Duplex      2Story             6
# 2823        NAmes        PosA        Norm      1Fam      1Story             7
#
#       overall_cond  year_built  year_remod_add roof_style roof_matl  \
# 12               7        1880            2007      Gable   CompShg
# 93               5        1979            1979      Gable   CompShg
# 114              2        1947            1950      Gable   CompShg
# 146              5        2003            2003      Gable   CompShg
# 183              5        1952            1952      Gable   CompShg
# 240              6        1952            2002      Gable   CompShg
# 249              4        1939            1950      Gable   CompShg
# 256              5        1954            1954      Gable   CompShg
# 390              5        1978            1978      Gable   CompShg
# 437              5        1955            1955      Gable   CompShg
# ...            ...         ...             ...        ...       ...
# 2532             3        1957            1957      Gable   CompShg
# 2579             5        1965            1965        Hip   CompShg
# 2604             6        1945            1995      Gable   CompShg
# 2665             5        1951            1951      Gable   CompShg
# 2670             3        1955            1955      Gable   CompShg
# 2673             5        1979            1979      Gable   CompShg
# 2677             5        1977            1977      Gable   CompShg
# 2706             6        1949            1950        Hip   CompShg
# 2754             7        1981            1981      Gable   CompShg
# 2823             5        1959            1959        Hip   CompShg
#
#      exterior_1st  ... functional fireplaces  fireplace_qu garage_type  \
# 12        HdBoard  ...        Mod          1            TA      Attchd
# 93        HdBoard  ...        Typ          0           NaN      Attchd
# 114       Wd Sdng  ...       Min2          0           NaN         NaN
# 146       HdBoard  ...        Typ          1            Ex     BuiltIn
# 183       AsbShng  ...        Sal          0           NaN      Attchd
# 240       Wd Sdng  ...        Typ          1            Ex      Attchd
# 249       MetalSd  ...       Maj2          0           NaN      Detchd
# 256       Wd Sdng  ...       Min2          1            Gd         NaN
# 390       VinylSd  ...        Typ          0           NaN      Attchd
# 437       AsbShng  ...        Typ          0           NaN         NaN
# ...           ...  ...        ...        ...           ...         ...
# 2532      Wd Sdng  ...        Typ          0           NaN      Detchd
# 2579      AsphShn  ...        Typ          0           NaN         NaN
# 2604      Plywood  ...       Min2          0           NaN      Attchd
# 2665      Wd Sdng  ...       Min1          1            Gd      Attchd
# 2670      AsbShng  ...        Typ          0           NaN         NaN
# 2673      HdBoard  ...        Typ          0           NaN      Attchd
# 2677      Plywood  ...        Typ          2            TA      Detchd
# 2706      VinylSd  ...        Typ          0           NaN      Detchd
# 2754      Wd Sdng  ...        Typ          2            TA      Attchd
# 2823      Plywood  ...        Typ          1            Gd      Attchd
#
#      garage_yr_blt garage_finish garage_cars garage_area garage_qual  \
# 12          1900.0           Unf         2.0       576.0          TA
# 93          1979.0           Unf         2.0       400.0          TA
# 114            NaN           NaN         0.0         0.0         NaN
# 146         2003.0           RFn         2.0       672.0          TA
# 183         1952.0           Unf         2.0       487.0          Fa
# 240         2002.0           RFn         2.0       569.0          TA
# 249         1950.0           Unf         1.0       256.0          TA
# 256            NaN           NaN         0.0         0.0         NaN
# 390         1978.0           Unf         2.0       539.0          TA
# 437            NaN           NaN         0.0         0.0         NaN
# ...            ...           ...         ...         ...         ...
# 2532        1957.0           Unf         1.0       290.0          TA
# 2579           NaN           NaN         0.0         0.0         NaN
# 2604        1925.0           Unf         1.0       164.0          TA
# 2665        1951.0           Fin         2.0       400.0          TA
# 2670           NaN           NaN         0.0         0.0         NaN
# 2673        1979.0           Unf         2.0       410.0          TA
# 2677        1977.0           Unf         2.0       630.0          TA
# 2706        1955.0           Unf         1.0       287.0          TA
# 2754        1981.0           Unf         2.0       612.0          TA
# 2823        1959.0           Unf         2.0       484.0          TA
#
#      garage_cond  paved_drive wood_deck_sf  open_porch_sf  enclosed_porch  \
# 12            TA            P            0              0               0
# 93            TA            Y            0              0               0
# 114          NaN            N            0              0             100
# 146           TA            Y            0              0             177
# 183           Po            N            0              0               0
# 240           TA            Y            0            189              36
# 249           Fa            N           48              0               0
# 256          NaN            N            0             36             190
# 390           TA            Y            0              0               0
# 437          NaN            N            0              0               0
# ...          ...          ...          ...            ...             ...
# 2532          TA            N          186              0               0
# 2579         NaN            Y            0              0               0
# 2604          TA            P            0             48               0
# 2665          TA            Y          174             24             120
# 2670         NaN            N            0              0               0
# 2673          TA            Y            0              0               0
# 2677          TA            Y            0              0               0
# 2706          Fa            Y            0              0               0
# 2754          TA            Y            0              0               0
# 2823          TA            Y            0             68               0
#
#       3ssn_porch screen_porch pool_area pool_qc  fence  misc_feature  \
# 12             0            0         0     NaN    NaN           NaN
# 93             0            0         0     NaN  GdPrv           NaN
# 114            0            0         0     NaN    NaN           NaN
# 146            0            0         0     NaN    NaN           NaN
# 183            0            0         0     NaN    NaN           NaN
# 240            0          348         0     NaN    NaN           NaN
# 249            0            0         0     NaN    NaN           NaN
# 256            0            0         0     NaN    NaN           NaN
# 390            0            0         0     NaN    NaN           NaN
# 437            0            0         0     NaN    NaN           NaN
# ...          ...          ...       ...     ...    ...           ...
# 2532           0            0         0     NaN    NaN           NaN
# 2579           0            0         0     NaN    NaN           NaN
# 2604           0            0         0     NaN    NaN           NaN
# 2665           0          228         0     NaN    NaN           NaN
# 2670           0            0         0     NaN    NaN           NaN
# 2673           0            0         0     NaN    NaN           NaN
# 2677           0            0         0     NaN    NaN           NaN
# 2706           0            0         0     NaN    NaN           NaN
# 2754           0            0         0     NaN    NaN           NaN
# 2823           0          227         0     NaN    NaN           NaN
#
#       misc_val  mo_sold  yr_sold  sale_type  saleprice
# 12           0        6     2009        WD    131000.0
# 93           0        6     2009        WD    118858.0
# 114          0        6     2009        WD     63900.0
# 146          0        7     2009      ConLD   198500.0
# 183          0        2     2008        WD     13100.0
# 240          0        4     2006        WD    135000.0
# 249          0        3     2007        WD     68104.0
# 256          0        4     2006        WD     93000.0
# 390          0        4     2010        WD    112000.0
# 437          0        6     2008        WD     82000.0
# ...        ...      ...      ...        ...        ...
# 2532         0        1     2009        WD         NaN
# 2579         0        5     2010        WD         NaN
# 2604         0        6     2008        WD         NaN
# 2665         0        6     2007        WD         NaN
# 2670         0        9     2007        WD         NaN
# 2673         0        6     2009        WD         NaN
# 2677         0       10     2007        WD         NaN
# 2706         0        7     2008        WD         NaN
# 2754         0        5     2009        WD         NaN
# 2823         0        6     2006        WD         NaN
#
# [80 rows x 81 columns]

# %%
comb['bsmt_cond'].fillna(value='NA',inplace=True)            #Replace missing values with 'NA'

# %%
comb[comb['bsmt_cond'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, pid, ms_subclass, ms_zoning, lot_frontage, lot_area, street, alley, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod_add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, fireplace_qu, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, pool_qc, fence, misc_feature, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []
#
# [0 rows x 81 columns]

# %% [markdown]
# #### Continue to provide default values to missing data:

# %%
def eda(df):
    #Replace missing bsmt_qual values with 'NA'
    df['bsmt_qual'].fillna(value='NA',inplace=True)
    #Replace missing bsmt_exposure values with 'NA'
    df['bsmt_exposure'].fillna(value='NA',inplace=True)
    #Replace missing bsmtfin_type_1 values with 'NA'
    df['bsmtfin_type_1'].fillna(value='NA',inplace=True)
    #Replace missing bsmtfin_sf_1 values with 'zero
    df['bsmtfin_sf_1'] = df['bsmtfin_sf_1'].fillna(0)  
    #Replace missing bsmtfin_type_1 values with 'NA'
    df['bsmtfin_type_2'].fillna(value='NA',inplace=True)
    #Replace missing bsmtfin_sf_2 values with 'zero
    df['bsmtfin_sf_2'] = df['bsmtfin_sf_2'].fillna(0) 
    #Replace missing electrical values with 'NA'
    df['electrical'].fillna(value='NA',inplace=True)
    #Replace missing bsmt_unf_sf values with 'zero
    df['bsmt_unf_sf'] = df['bsmt_unf_sf'].fillna(0)  
    #Replace missing total_bsmt_sf values with 'zero
    df['total_bsmt_sf'] = df['total_bsmt_sf'].fillna(0) 
    #Replace missing bsmt_full_bath values with 'zero
    df['bsmt_full_bath'] = df['bsmt_full_bath'].fillna(0) 
    #Replace missing bsmt_half_bath values with 'zero
    df['bsmt_half_bath'] = df['bsmt_half_bath'].fillna(0) 
    #Replace missing fireplace_qu values with 'NA'
    df['fireplace_qu'].fillna(value='NA',inplace=True)
    #Replace missing garage_type values with 'NA'
    df['garage_type'].fillna(value='NA',inplace=True)
    #Replace missing bsmt_half_bath values with with median value
    df['garage_yr_blt'] = df['garage_yr_blt'].fillna(1979) 
    #Replace missing garage_finish values with 'NA'
    df['garage_finish'].fillna(value='NA',inplace=True)
    df['garage_cars'] = df['garage_cars'].fillna(0) 
    #Replace missing garage_area values with 'zero
    df['garage_area'] = df['garage_area'].fillna(0) 
    #Replace missing garage_qual values with 'NA'
    df['garage_qual'].fillna(value='NA',inplace=True)
    #Replace missing garage_cond values with 'NA'
    df['garage_cond'].fillna(value='NA',inplace=True)
    #Replace missing pool_qc values with 'NA'
    df['pool_qc'].fillna(value='NA',inplace=True)
    #Replace missing fence values with 'NA'
    df['fence'].fillna(value='NA',inplace=True)
    #Replace missing misc_feature values with 'NA'
    df['misc_feature'].fillna(value='NA',inplace=True)
    return  None 

eda(comb)

# %%
comb.isnull().sum()    #All columns null (except 'salesprice') have been filled up.
# Out:
# id                0
# pid               0
# ms_subclass       0
# ms_zoning         0
# lot_frontage      0
# lot_area          0
# street            0
# alley             0
# lot_shape         0
# land_contour      0
#                ...
# screen_porch      0
# pool_area         0
# pool_qc           0
# fence             0
# misc_feature      0
# misc_val          0
# mo_sold           0
# yr_sold           0
# sale_type         0
# saleprice       879
# Length: 81, dtype: int64

# %%
#Determine the Variance of the Features
comb.var().sort_values(ascending=False).tail(30)
# Out:
# 2nd_flr_sf         183522.888638
# 1st_flr_sf         153578.465945
# garage_area         46305.529198
# mas_vnr_area        31910.300605
# bsmtfin_sf_2        28609.046368
# wood_deck_sf        15967.244320
# open_porch_sf        4554.009294
# enclosed_porch       4113.818916
# screen_porch         3145.793099
# low_qual_fin_sf      2144.663340
#                        ...
# yr_sold                 1.733470
# overall_cond            1.235514
# bedroom_abvgr           0.685139
# garage_cars             0.579329
# fireplaces              0.419802
# full_bath               0.305743
# bsmt_full_bath          0.275375
# half_bath               0.252636
# bsmt_half_bath          0.060111
# kitchen_abvgr           0.045829
# Length: 30, dtype: float64

# %%
# Based on above, Variance < 1 will be dropped
comb.drop('kitchen_abvgr', axis=1, inplace=True)
comb.drop('bsmt_half_bath', axis=1, inplace=True)
comb.drop('half_bath', axis=1, inplace=True)
comb.drop('bsmt_full_bath', axis=1, inplace=True)
comb.drop('full_bath', axis=1, inplace=True)
comb.drop('bedroom_abvgr', axis=1, inplace=True)
comb.drop('garage_cars', axis=1, inplace=True)

# %%
def dummys(df):
    df = pd.get_dummies(df, columns=['ms_zoning'
                                     ,'condition_2', 'bldg_type', 'house_style' 
                                     ,'roof_style'
                                     ,'exterior_2nd'
                                     ,'heating' 
                                     ,'central_air' 
                                     ,'garage_type'
                                    ], drop_first=True)
    return df

comb_dum = dummys(comb)

# %%
def str_to_ord(df):
    replace={'lot_shape':{'Reg':3,'IR1':2,'IR2':1,'IR3':0},\
             'utilities':{'AllPub':3,'NoSewr':2,'NoSeWa':1,'ELO':0},\
             'land_slope':{'Gtl':2,'Mod':1,'Sev':0},\
             'exter_qual':{'Ex':4,'Gd':3,'TA':2,'Fa':1,'Po':0},\
             'exter_cond':{'Ex':4,'Gd':3,'TA':2,'Fa':1,'Po':0},\
             'bsmt_qual':{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'NA':0},\
             'bsmt_cond':{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'NA':0},\
             'bsmt_exposure':{'Gd':4,'Av':3,'Mn':2,'No':1,'NA':0},\
             'bsmtfin_type_1':{'GLQ':6,'ALQ':5,'BLQ':4,'Rec':3,'LwQ':2,'Unf':1,'NA':0},\
             'bsmtfin_type_2':{'GLQ':6,'ALQ':5,'BLQ':4,'Rec':3,'LwQ':2,'Unf':1,'NA':0},\
             'heating_qc':{'Ex':4,'Gd':3,'TA':2,'Fa':1,'Po':0},\
             'electrical':{'SBrkr':4,'FuseA':3,'FuseF':2,'FuseP':1,'Mix':0},\
             'kitchen_qual':{'Ex':4,'Gd':3,'TA':2,'Fa':1,'Po':0},\
             'functional':{'Typ':7,'Min1':6,'Min2':5,'Mod':4,'Maj1':3,'Maj2':2,'Sev':1,'Sal':0},\
             'fireplace_qu':{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'NA':0},\
             'garage_finish':{'Fin':3,'RFn':2,'Unf':1,'NA':0},\
             'garage_qual':{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'NA':0},\
             'garage_cond':{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'NA':0},\
             'paved_drive':{'Y':2,'P':1,'N':0},\
             'pool_qc':{'Ex':4,'Gd':3,'TA':2,'Fa':1,'NA':0},\
             'fence':{'GdPrv':4,'MnPrv':3,'GdWo':2,'MnWw':1,'NA':0}}
    df.replace(replace,inplace=True,method=None)
    return None

str_to_ord(comb_dum)

# %%
comb_dum.dtypes
# Out:
# id                       int64
# pid                      int64
# ms_subclass              int64
# lot_frontage           float64
# lot_area                 int64
# street                  object
# alley                   object
# lot_shape                int64
# land_contour            object
# utilities               object
#                         ...
# heating_Grav             uint8
# heating_OthW             uint8
# heating_Wall             uint8
# central_air_Y            uint8
# garage_type_Attchd       uint8
# garage_type_Basment      uint8
# garage_type_BuiltIn      uint8
# garage_type_CarPort      uint8
# garage_type_Detchd       uint8
# garage_type_NA           uint8
# Length: 122, dtype: object

# %% [markdown]
# Datatype Correction:

# %%
def dtype_corr(df):
    df[['lot_frontage']]=df[['lot_frontage']].astype(int)
    df[['utilities']]=df[['utilities']].astype(int)
    return None 

dtype_corr(comb_dum)

# %%
#move shareprince to the last column position
cols = list(comb_dum.columns.values) #Make a list of all of the columns in the df
cols.pop(cols.index('saleprice')) #Remove b from list
comb_dum = comb_dum[cols+['saleprice']] #Create new dataframe with columns in the order y

# %%
max(comb_dum.isnull().sum())
# Out:
# 879

# %%
comb_dum.to_csv('../datasets/comb_dum.csv' ,index=False)
